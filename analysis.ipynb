# %%
# %pip install pandas numpy matplotlib pyfixest
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 1.2 MB/s  0:00:02 eta 0:00:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 2.7 MB/s  0:00:13m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 41.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 42.2 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.2/607.2 kB 34.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 19.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 1.5 MB/s  0:00:30m0:00:0100:020m
# ...
#   Attempting uninstall: scipy0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/19 [typing-extensions]
#     Found existing installation: scipy 1.17.1━━━━━━━━━━━━━━━━━  2/19 [typing-extensions]
#     Uninstalling scipy-1.17.1:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/19 [scipy]ensions]
#       Successfully uninstalled scipy-1.17.1━━━━━━━━━━━━━━━━━━━━━━━  5/19 [scipy]
# ...

# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pyfixest


import os

folder_path = "../output/simulations"

# %% [markdown]
# # Tests

# %% [markdown]
# ## Test 1
#
# - No uncertainty
# - Same fixed cost for begining and mid year
#
# Increasing both fixed cost should increase the size of the SS band.

# %%
panel_1 = pd.read_csv(os.path.join(folder_path,"panel_data_s11.csv"))
panel_2 = pd.read_csv(os.path.join(folder_path,"panel_data_s12.csv"))

fix, ax = plt.subplots()
panel_1.query('firm_id == 1').plot(x = "year",y = 'I_total',ax =ax,label = "Low F")
panel_2.query('firm_id == 1').plot(x = "year",y = 'I_total',ax =ax,label = "High F")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## Test 2
#
# - No uncertainty
# - Different fixed cost between begin and mid-year
#
# Same fixed cost : Should invest in the semi period.
# Increasing the fixed cost should push the firm to invest in the other semi period.

# %%
panel_1 = pd.read_csv(os.path.join(folder_path,"panel_data_s21.csv"))
panel_2 = pd.read_csv(os.path.join(folder_path,"panel_data_s22.csv"))

fix, ax = plt.subplots()
panel_1.query('firm_id == 1').plot(x = "year",y = 'I_total',ax =ax,label = "Low F")
panel_2.query('firm_id == 1').plot(x = "year",y = 'I',ax =ax,label = "High F")
# Out:
# <Axes: xlabel='year'>

# %%
panel_2.head(50)
# Out:
#     firm_id  year         K             D        D_half     sigma  sigma_half  \
# 0         1     1  1.000000      6.042165   1263.393052  2.718282    2.718282
# 1         1     2  1.899293     31.849457  21577.042989  2.718282    2.718282
# 2         1     3  1.801828   1631.074130    119.484694  2.718282    2.718282
# 3         1     4  1.825065  89456.101147   4726.197769  2.718282    2.718282
# 4         1     5  1.819525    204.021213    540.532205  2.718282    2.718282
# 5         1     6  1.820845   3850.515195    465.498992  2.718282    2.718282
# 6         1     7  1.820531    996.238372   1110.078553  2.718282    2.718282
# 7         1     8  1.820606     13.617546      8.711354  2.718282    2.718282
# 8         1     9  1.820588   3107.586028   2102.979448  2.718282    2.718282
# 9         1    10  1.820592  15711.702556   1235.856971  2.718282    2.718282
# 10        1    11  1.820591    751.161142  98710.498887  2.718282    2.718282
# ...

# %%
# %pip install pandas numpy matplotlib pyfixest
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 92.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 76.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 96.7 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 63.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 87.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.2/607.2 kB 71.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 86.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 62.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 93.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 90.6 MB/s  0:00:006m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 92.8 MB/s  0:00:00
# ...

# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pyfixest


import os

folder_path = "output/simulations"

# %%
panel_data = pd.read_csv(os.path.join(folder_path,"panel_data.csv"))

# %%
panel_data
# Out:
#        firm_id  year         K         D    D_half     sigma  sigma_half  \
# 0            1     1  1.000000  0.724970  0.771419  0.087795    0.070325
# 1            1     2  0.958516  0.737264  0.822899  0.057334    0.062376
# 2            1     3  0.918873  0.862174  0.842495  0.072008    0.078103
# 3            1     4  0.880988  0.994798  1.048607  0.063117    0.054161
# 4            1     5  0.845098  1.025168  1.024653  0.069163    0.057748
# ...        ...   ...       ...       ...       ...       ...         ...
# 49995     1000    46  0.237165  1.077202  1.001221  0.096573    0.092277
# 49996     1000    47  0.233222  1.075788  1.213137  0.096241    0.092440
# 49997     1000    48  0.229618  1.251898  1.270862  0.077318    0.070716
# 49998     1000    49  0.226191  1.360039  1.232326  0.070648    0.072079
# 49999     1000    50  0.222829  1.270153  1.197423  0.071271    0.060440
#
#           log_D  log_D_half  log_sigma  log_sigma_half         I   Delta_I  \
# ...

# %%
panel_data.query('firm_id == 1').plot(x = "year",y = "K")
plt.grid()

# %%
panel_data.groupby('year').I_rate.mean().plot()
plt.yscale("log")

# %%
df = pd.read_csv(os.path.join("output/solutions/with_ac/policy_functions.csv"))

# %%
df[df.K == df.K.max()]
# Out:
#             K         D     sigma     log_D  log_sigma  I_initial         V
# 285  0.000123  0.587324  0.050694 -0.532178  -2.981951   0.000002  0.042658
# 286  0.000123  0.766371  0.050694 -0.266089  -2.981951   0.000002  0.043557
# 287  0.000123  1.000000  0.050694  0.000000  -2.981951   0.000002  0.044577
# 288  0.000123  1.304851  0.050694  0.266089  -2.981951   0.000002  0.045740
# 289  0.000123  1.702637  0.050694  0.532178  -2.981951   0.000002  0.047073
# 290  0.000123  0.587324  0.100000 -0.532178  -2.302585   0.000002  0.042658
# 291  0.000123  0.766371  0.100000 -0.266089  -2.302585   0.000002  0.043557
# 292  0.000123  1.000000  0.100000  0.000000  -2.302585   0.000002  0.044577
# 293  0.000123  1.304851  0.100000  0.266089  -2.302585   0.000002  0.045740
# 294  0.000123  1.702637  0.100000  0.532178  -2.302585   0.000002  0.047073
# 295  0.000123  0.587324  0.197263 -0.532178  -1.623219   0.000002  0.042658
# ...

# %%
df.groupby('K').V.mean().sort_values()
# Out:
# K
# 0.000004    0.044171
# 0.000005    0.044201
# 0.000006    0.044231
# 0.000007    0.044261
# 0.000008    0.044292
# 0.000010    0.044323
# 0.000012    0.044353
# 0.000014    0.044384
# 0.000017    0.044415
# 0.000021    0.044446
# 0.000025    0.044477
# 0.000029    0.044507
# 0.000035    0.044537
# 0.000042    0.044568
# 0.000050    0.044598
# 0.000060    0.044627
# 0.000072    0.044654
# 0.000086    0.044679
# 0.000103    0.044701
# 0.000123    0.044721
# Name: V, dtype: float64

# %%
# %pip install pandas numpy matplotlib pyfixest
# Out:
# ...
#   Using cached scipy-1.15.3-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached scipy-1.15.3-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.17.1
#     Uninstalling scipy-1.17.1:
#       Successfully uninstalled scipy-1.17.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pyfixest as pf


import os

folder_path = "../output/simulations_uncertainty_variable_fixed_cost_Lamont"

# %% [markdown]
# # Tests

# %%
panel["share_Delta_I"] = (panel['Delta_I']/panel.I_total).fillna(0)

# %%
test = 1
panel = pd.read_csv(os.path.join(folder_path,f"panel_all_fixed_costs.csv"))
F_mid_year = np.sort(panel.F_mid_year.unique())
R2 = []
for F in F_mid_year:
    df = panel.query('F_mid_year == @F')
    R2.append(pf.feols('E_last_semester ~ I_total | firm_id', data = df)._r2)

# %%
plt.plot(F_mid_year,R2)
plt.ylabel("R2")
plt.xlabel("F_mid_year")
# Out:
# Text(0.5, 0, 'F_mid_year')

# %%
panel_1
